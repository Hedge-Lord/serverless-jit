# %%
import subprocess, shutil, glob, os, pandas as pd, matplotlib.pyplot as plt, time

NUM_RUNS   = 10
RUN_SCRIPT = "./run.sh"

def run_benchmark(idx: int):
    subprocess.run(["bash", RUN_SCRIPT], check=True)
    shutil.move("cold_results.csv", f"cold_results_{idx}")
    shutil.move("warm_results.csv", f"warm_results_{idx}")

for i in range(NUM_RUNS):
    run_benchmark(i)
# Out:
# Running benchmark to generate profile data...
# CompileCommand: DumpReplay WordCountBenchmark.wordCount bool DumpReplay = true
# # Compiler replay data is saved as: replay_pid47913_compid97.log
# # Compiler replay data is saved as: replay_pid47913_compid208.log
# # Compiler replay data is saved as: replay_pid47913_compid213.log
# # Compiler replay data is saved as: replay_pid47913_compid217.log
# Ran 2,000 invocations
# Average: 583.7 µs | p95: 663 µs
# Selecting largest replay file...
# Original replay: replay_pid47913_compid217.log
# Stripped replay saved as: replay_pid47913_compid217_nocompile.log
# Running benchmark with no profile injection...
# Ran 2,000 invocations
# Average: 522.4 µs | p95: 568 µs
# Running benchmark with profile injection (no forced compile)...
# ProfileInjection: Starting profile injection
# Resolving klass jdk/internal/reflect/Reflection at 153
# Resolving klass java/util/Objects at 199
# Resolving klass jdk/internal/loader/BootLoader at 227
# Resolving klass jdk/internal/reflect/ReflectionFactory at 255
# Resolving klass java/lang/Class$ReflectionData at 363
# Resolving klass jdk/internal/misc/PreviewFeatures at 558
# Resolving klass java/lang/Class$Atomic at 843
# Resolving klass java/lang/PublicMethods$MethodList at 963
# Resolving klass jdk/internal/reflect/ReflectionFactory$GetReflectionFactoryAction at 1009
# Resolving klass java/lang/StringUTF16 at 48
# Resolving klass java/util/regex/Pattern at 700
# Resolving klass [Ljava/lang/String; at 799
# Resolving klass jdk/internal/reflect/Reflection at 90
# Resolving klass [Ljava/lang/Class; at 134
# Resolving klass jdk/internal/reflect/ReflectionFactory at 250
# Resolving klass jdk/internal/misc/VM at 256
# Resolving klass jdk/internal/reflect/Reflection at 25
# Resolving klass java/lang/reflect/Modifier at 101
# Resolving klass java/lang/CharacterData00 at 20
# Resolving klass jdk/internal/math/FloatingDecimal at 109
# Resolving klass jdk/internal/ref/Cleaner at 36
# Resolving klass java/lang/Void at 50
# Resolving klass [Ljava/lang/Object; at 99
# Resolving klass [Ljava/lang/Class; at 101
# Resolving klass jdk/internal/reflect/MagicAccessorImpl at 2
# Resolving klass java/lang/invoke/MethodHandleNatives at 23
# Resolving klass java/util/ArrayList$SubList at 276
# Resolving klass java/lang/Object at 4
# Resolving klass java/lang/String at 9
# Resolving klass java/nio/file/Paths at 12
# Resolving klass java/nio/charset/StandardCharsets at 18
# Resolving klass java/nio/file/Files at 24
# Resolving klass java/lang/Character at 46
# Resolving klass java/lang/Math at 62
# Resolving klass java/util/List at 86
# Resolving klass java/lang/System at 102
# Resolving klass java/lang/Double at 130
# Resolving klass java/lang/Integer at 136
# Resolving klass java/util/ArrayList at 144
# Resolving klass java/nio/file/OpenOption at 148
# Resolving klass java/io/PrintWriter at 154
# Resolving klass java/io/BufferedWriter at 156
# Resolving klass java/lang/Long at 170
# Resolving klass java/lang/Exception at 278
# ProfileInjection: Profile injection completed successfully - resuming normal execution
# ProfileInjection: Successfully injected profile data from replay_pid47913_compid217_nocompile.log
# Ran 2,000 invocations
# Average: 451.2 µs | p95: 492 µs
# Done.
# - Cold results : cold_results.csv
# - Warm results : warm_results.csv
# - Profiles used: replay_pid47913_compid217_nocompile.log
# Running benchmark to generate profile data...
# CompileCommand: DumpReplay WordCountBenchmark.wordCount bool DumpReplay = true
# # Compiler replay data is saved as: replay_pid47941_compid98.log
# # Compiler replay data is saved as: replay_pid47941_compid207.log
# # Compiler replay data is saved as: replay_pid47941_compid212.log
# # Compiler replay data is saved as: replay_pid47941_compid214.log
# Ran 2,000 invocations
# Average: 542.4 µs | p95: 598 µs
# Selecting largest replay file...
# Original replay: replay_pid47941_compid214.log
# Stripped replay saved as: replay_pid47941_compid214_nocompile.log
# Running benchmark with no profile injection...
# Ran 2,000 invocations
# Average: 532.9 µs | p95: 585 µs
# Running benchmark with profile injection (no forced compile)...
# ProfileInjection: Starting profile injection
# Resolving klass jdk/internal/reflect/Reflection at 153
# Resolving klass java/util/Objects at 199
# Resolving klass jdk/internal/loader/BootLoader at 227
# Resolving klass jdk/internal/reflect/ReflectionFactory at 255
# Resolving klass java/lang/Class$ReflectionData at 363
# Resolving klass jdk/internal/misc/PreviewFeatures at 558
# Resolving klass java/lang/Class$Atomic at 843
# Resolving klass java/lang/PublicMethods$MethodList at 963
# Resolving klass jdk/internal/reflect/ReflectionFactory$GetReflectionFactoryAction at 1009
# Resolving klass java/lang/StringUTF16 at 48
# Resolving klass java/util/regex/Pattern at 700
# Resolving klass [Ljava/lang/String; at 799
# Resolving klass jdk/internal/reflect/Reflection at 90
# Resolving klass [Ljava/lang/Class; at 134
# Resolving klass jdk/internal/reflect/ReflectionFactory at 250
# Resolving klass jdk/internal/misc/VM at 256
# Resolving klass jdk/internal/reflect/Reflection at 25
# Resolving klass java/lang/reflect/Modifier at 101
# Resolving klass java/lang/CharacterData00 at 20
# Resolving klass jdk/internal/math/FloatingDecimal at 109
# Resolving klass jdk/internal/ref/Cleaner at 36
# Resolving klass java/lang/Void at 50
# Resolving klass [Ljava/lang/Object; at 99
# Resolving klass [Ljava/lang/Class; at 101
# Resolving klass jdk/internal/reflect/MagicAccessorImpl at 2
# Resolving klass java/lang/invoke/MethodHandleNatives at 23
# Resolving klass java/util/ArrayList$SubList at 276
# Resolving klass java/lang/Object at 4
# Resolving klass java/lang/String at 9
# Resolving klass java/nio/file/Paths at 12
# Resolving klass java/nio/charset/StandardCharsets at 18
# Resolving klass java/nio/file/Files at 24
# Resolving klass java/lang/Character at 46
# Resolving klass java/lang/Math at 62
# Resolving klass java/util/List at 86
# Resolving klass java/lang/System at 102
# Resolving klass java/lang/Double at 130
# Resolving klass java/lang/Integer at 136
# Resolving klass java/util/ArrayList at 144
# Resolving klass java/nio/file/OpenOption at 148
# Resolving klass java/io/PrintWriter at 154
# Resolving klass java/io/BufferedWriter at 156
# Resolving klass java/lang/Long at 170
# Resolving klass java/lang/Exception at 278
# ProfileInjection: Profile injection completed successfully - resuming normal execution
# ProfileInjection: Successfully injected profile data from replay_pid47941_compid214_nocompile.log
# Ran 2,000 invocations
# Average: 494.0 µs | p95: 571 µs
# Done.
# - Cold results : cold_results.csv
# - Warm results : warm_results.csv
# - Profiles used: replay_pid47941_compid214_nocompile.log
# Running benchmark to generate profile data...
# CompileCommand: DumpReplay WordCountBenchmark.wordCount bool DumpReplay = true
# # Compiler replay data is saved as: replay_pid47968_compid99.log
# # Compiler replay data is saved as: replay_pid47968_compid207.log
# # Compiler replay data is saved as: replay_pid47968_compid212.log
# # Compiler replay data is saved as: replay_pid47968_compid213.log
# Ran 2,000 invocations
# Average: 561.0 µs | p95: 653 µs
# Selecting largest replay file...
# Original replay: replay_pid47968_compid213.log
# Stripped replay saved as: replay_pid47968_compid213_nocompile.log
# Running benchmark with no profile injection...
# Ran 2,000 invocations
# Average: 552.3 µs | p95: 596 µs
# Running benchmark with profile injection (no forced compile)...
# ProfileInjection: Starting profile injection
# Resolving klass jdk/internal/reflect/Reflection at 153
# Resolving klass java/util/Objects at 199
# Resolving klass jdk/internal/loader/BootLoader at 227
# Resolving klass jdk/internal/reflect/ReflectionFactory at 255
# Resolving klass java/lang/Class$ReflectionData at 363
# Resolving klass jdk/internal/misc/PreviewFeatures at 558
# Resolving klass java/lang/Class$Atomic at 843
# Resolving klass java/lang/PublicMethods$MethodList at 963
# Resolving klass jdk/internal/reflect/ReflectionFactory$GetReflectionFactoryAction at 1009
# Resolving klass java/lang/StringUTF16 at 48
# Resolving klass java/util/regex/Pattern at 700
# Resolving klass [Ljava/lang/String; at 799
# Resolving klass jdk/internal/reflect/Reflection at 90
# Resolving klass [Ljava/lang/Class; at 134
# Resolving klass jdk/internal/reflect/ReflectionFactory at 250
# Resolving klass jdk/internal/misc/VM at 256
# Resolving klass jdk/internal/reflect/Reflection at 25
# Resolving klass java/lang/reflect/Modifier at 101
# Resolving klass java/lang/CharacterData00 at 20
# Resolving klass jdk/internal/math/FloatingDecimal at 109
# Resolving klass jdk/internal/ref/Cleaner at 36
# Resolving klass java/lang/Void at 50
# Resolving klass [Ljava/lang/Object; at 99
# Resolving klass [Ljava/lang/Class; at 101
# Resolving klass jdk/internal/reflect/MagicAccessorImpl at 2
# Resolving klass java/lang/invoke/MethodHandleNatives at 23
# Resolving klass java/util/ArrayList$SubList at 276
# Resolving klass java/lang/Object at 4
# Resolving klass java/lang/String at 9
# Resolving klass java/nio/file/Paths at 12
# Resolving klass java/nio/charset/StandardCharsets at 18
# Resolving klass java/nio/file/Files at 24
# Resolving klass java/lang/Character at 46
# Resolving klass java/lang/Math at 62
# Resolving klass java/util/List at 86
# Resolving klass java/lang/System at 102
# Resolving klass java/lang/Double at 130
# Resolving klass java/lang/Integer at 136
# Resolving klass java/util/ArrayList at 144
# Resolving klass java/nio/file/OpenOption at 148
# Resolving klass java/io/PrintWriter at 154
# Resolving klass java/io/BufferedWriter at 156
# Resolving klass java/lang/Long at 170
# Resolving klass java/lang/Exception at 278
# ProfileInjection: Profile injection completed successfully - resuming normal execution
# ProfileInjection: Successfully injected profile data from replay_pid47968_compid213_nocompile.log
# Ran 2,000 invocations
# Average: 564.2 µs | p95: 607 µs
# Done.
# - Cold results : cold_results.csv
# - Warm results : warm_results.csv
# - Profiles used: replay_pid47968_compid213_nocompile.log
# Running benchmark to generate profile data...
# CompileCommand: DumpReplay WordCountBenchmark.wordCount bool DumpReplay = true
# # Compiler replay data is saved as: replay_pid48002_compid97.log
# # Compiler replay data is saved as: replay_pid48002_compid207.log
# # Compiler replay data is saved as: replay_pid48002_compid212.log
# # Compiler replay data is saved as: replay_pid48002_compid215.log
# Ran 2,000 invocations
# Average: 555.4 µs | p95: 634 µs
# Selecting largest replay file...
# Original replay: replay_pid48002_compid215.log
# Stripped replay saved as: replay_pid48002_compid215_nocompile.log
# Running benchmark with no profile injection...
# Ran 2,000 invocations
# Average: 563.2 µs | p95: 652 µs
# Running benchmark with profile injection (no forced compile)...
# ProfileInjection: Starting profile injection
# Resolving klass jdk/internal/reflect/Reflection at 153
# Resolving klass java/util/Objects at 199
# Resolving klass jdk/internal/loader/BootLoader at 227
# Resolving klass jdk/internal/reflect/ReflectionFactory at 255
# Resolving klass java/lang/Class$ReflectionData at 363
# Resolving klass jdk/internal/misc/PreviewFeatures at 558
# Resolving klass java/lang/Class$Atomic at 843
# Resolving klass java/lang/PublicMethods$MethodList at 963
# Resolving klass jdk/internal/reflect/ReflectionFactory$GetReflectionFactoryAction at 1009
# Resolving klass java/lang/StringUTF16 at 48
# Resolving klass java/util/regex/Pattern at 700
# Resolving klass [Ljava/lang/String; at 799
# Resolving klass jdk/internal/reflect/Reflection at 90
# Resolving klass [Ljava/lang/Class; at 134
# Resolving klass jdk/internal/reflect/ReflectionFactory at 250
# Resolving klass jdk/internal/misc/VM at 256
# Resolving klass jdk/internal/reflect/Reflection at 25
# Resolving klass java/lang/reflect/Modifier at 101
# Resolving klass java/lang/CharacterData00 at 20
# Resolving klass jdk/internal/math/FloatingDecimal at 109
# Resolving klass jdk/internal/ref/Cleaner at 36
# Resolving klass java/lang/Void at 50
# Resolving klass [Ljava/lang/Object; at 99
# Resolving klass [Ljava/lang/Class; at 101
# Resolving klass jdk/internal/reflect/MagicAccessorImpl at 2
# Resolving klass java/lang/invoke/MethodHandleNatives at 23
# Resolving klass java/util/ArrayList$SubList at 276
# Resolving klass java/lang/Object at 4
# Resolving klass java/lang/String at 9
# Resolving klass java/nio/file/Paths at 12
# Resolving klass java/nio/charset/StandardCharsets at 18
# Resolving klass java/nio/file/Files at 24
# Resolving klass java/lang/Character at 46
# Resolving klass java/lang/Math at 62
# Resolving klass java/util/List at 86
# Resolving klass java/lang/System at 102
# Resolving klass java/lang/Double at 130
# Resolving klass java/lang/Integer at 136
# Resolving klass java/util/ArrayList at 144
# Resolving klass java/nio/file/OpenOption at 148
# Resolving klass java/io/PrintWriter at 154
# Resolving klass java/io/BufferedWriter at 156
# Resolving klass java/lang/Long at 170
# Resolving klass java/lang/Exception at 278
# ProfileInjection: Profile injection completed successfully - resuming normal execution
# ProfileInjection: Successfully injected profile data from replay_pid48002_compid215_nocompile.log
# Ran 2,000 invocations
# Average: 629.1 µs | p95: 681 µs
# Done.
# - Cold results : cold_results.csv
# - Warm results : warm_results.csv
# - Profiles used: replay_pid48002_compid215_nocompile.log
# Running benchmark to generate profile data...
# CompileCommand: DumpReplay WordCountBenchmark.wordCount bool DumpReplay = true
# # Compiler replay data is saved as: replay_pid48032_compid97.log
# # Compiler replay data is saved as: replay_pid48032_compid207.log
# # Compiler replay data is saved as: replay_pid48032_compid211.log
# # Compiler replay data is saved as: replay_pid48032_compid215.log
# Ran 2,000 invocations
# Average: 541.0 µs | p95: 606 µs
# Selecting largest replay file...
# Original replay: replay_pid48032_compid215.log
# Stripped replay saved as: replay_pid48032_compid215_nocompile.log
# Running benchmark with no profile injection...
# Ran 2,000 invocations
# Average: 565.2 µs | p95: 620 µs
# Running benchmark with profile injection (no forced compile)...
# ProfileInjection: Starting profile injection
# Resolving klass jdk/internal/reflect/Reflection at 153
# Resolving klass java/util/Objects at 199
# Resolving klass jdk/internal/loader/BootLoader at 227
# Resolving klass jdk/internal/reflect/ReflectionFactory at 255
# Resolving klass java/lang/Class$ReflectionData at 363
# Resolving klass jdk/internal/misc/PreviewFeatures at 558
# Resolving klass java/lang/Class$Atomic at 843
# Resolving klass java/lang/PublicMethods$MethodList at 963
# Resolving klass jdk/internal/reflect/ReflectionFactory$GetReflectionFactoryAction at 1009
# Resolving klass java/lang/StringUTF16 at 48
# Resolving klass java/util/regex/Pattern at 700
# Resolving klass [Ljava/lang/String; at 799
# Resolving klass jdk/internal/reflect/Reflection at 90
# Resolving klass [Ljava/lang/Class; at 134
# Resolving klass jdk/internal/reflect/ReflectionFactory at 250
# Resolving klass jdk/internal/misc/VM at 256
# Resolving klass jdk/internal/reflect/Reflection at 25
# Resolving klass java/lang/reflect/Modifier at 101
# Resolving klass java/lang/CharacterData00 at 20
# Resolving klass jdk/internal/math/FloatingDecimal at 109
# Resolving klass jdk/internal/ref/Cleaner at 36
# Resolving klass java/lang/Void at 50
# Resolving klass [Ljava/lang/Object; at 99
# Resolving klass [Ljava/lang/Class; at 101
# Resolving klass jdk/internal/reflect/MagicAccessorImpl at 2
# Resolving klass java/lang/invoke/MethodHandleNatives at 23
# Resolving klass java/util/ArrayList$SubList at 276
# Resolving klass java/lang/Object at 4
# Resolving klass java/lang/String at 9
# Resolving klass java/nio/file/Paths at 12
# Resolving klass java/nio/charset/StandardCharsets at 18
# Resolving klass java/nio/file/Files at 24
# Resolving klass java/lang/Character at 46
# Resolving klass java/lang/Math at 62
# Resolving klass java/util/List at 86
# Resolving klass java/lang/System at 102
# Resolving klass java/lang/Double at 130
# Resolving klass java/lang/Integer at 136
# Resolving klass java/util/ArrayList at 144
# Resolving klass java/nio/file/OpenOption at 148
# Resolving klass java/io/PrintWriter at 154
# Resolving klass java/io/BufferedWriter at 156
# Resolving klass java/lang/Long at 170
# Resolving klass java/lang/Exception at 278
# ProfileInjection: Profile injection completed successfully - resuming normal execution
# ProfileInjection: Successfully injected profile data from replay_pid48032_compid215_nocompile.log
# Ran 2,000 invocations
# Average: 555.2 µs | p95: 579 µs
# Done.
# - Cold results : cold_results.csv
# - Warm results : warm_results.csv
# - Profiles used: replay_pid48032_compid215_nocompile.log
# Running benchmark to generate profile data...
# CompileCommand: DumpReplay WordCountBenchmark.wordCount bool DumpReplay = true
# # Compiler replay data is saved as: replay_pid48059_compid97.log
# # Compiler replay data is saved as: replay_pid48059_compid205.log
# # Compiler replay data is saved as: replay_pid48059_compid210.log
# # Compiler replay data is saved as: replay_pid48059_compid213.log
# Ran 2,000 invocations
# Average: 531.1 µs | p95: 576 µs
# Selecting largest replay file...
# Original replay: replay_pid48059_compid213.log
# Stripped replay saved as: replay_pid48059_compid213_nocompile.log
# Running benchmark with no profile injection...
# Ran 2,000 invocations
# Average: 539.9 µs | p95: 575 µs
# Running benchmark with profile injection (no forced compile)...
# ProfileInjection: Starting profile injection
# Resolving klass jdk/internal/reflect/Reflection at 153
# Resolving klass java/util/Objects at 199
# Resolving klass jdk/internal/loader/BootLoader at 227
# Resolving klass jdk/internal/reflect/ReflectionFactory at 255
# Resolving klass java/lang/Class$ReflectionData at 363
# Resolving klass jdk/internal/misc/PreviewFeatures at 558
# Resolving klass java/lang/Class$Atomic at 843
# Resolving klass java/lang/PublicMethods$MethodList at 963
# Resolving klass jdk/internal/reflect/ReflectionFactory$GetReflectionFactoryAction at 1009
# Resolving klass java/lang/StringUTF16 at 48
# Resolving klass java/util/regex/Pattern at 700
# Resolving klass [Ljava/lang/String; at 799
# Resolving klass jdk/internal/reflect/Reflection at 90
# Resolving klass [Ljava/lang/Class; at 134
# Resolving klass jdk/internal/reflect/ReflectionFactory at 250
# Resolving klass jdk/internal/misc/VM at 256
# Resolving klass jdk/internal/reflect/Reflection at 25
# Resolving klass java/lang/reflect/Modifier at 101
# Resolving klass java/lang/CharacterData00 at 20
# Resolving klass jdk/internal/math/FloatingDecimal at 109
# Resolving klass jdk/internal/ref/Cleaner at 36
# Resolving klass java/lang/Void at 50
# Resolving klass [Ljava/lang/Object; at 99
# Resolving klass [Ljava/lang/Class; at 101
# Resolving klass jdk/internal/reflect/MagicAccessorImpl at 2
# Resolving klass java/lang/invoke/MethodHandleNatives at 23
# Resolving klass java/util/ArrayList$SubList at 276
# Resolving klass java/lang/Object at 4
# Resolving klass java/lang/String at 9
# Resolving klass java/nio/file/Paths at 12
# Resolving klass java/nio/charset/StandardCharsets at 18
# Resolving klass java/nio/file/Files at 24
# Resolving klass java/lang/Character at 46
# Resolving klass java/lang/Math at 62
# Resolving klass java/util/List at 86
# Resolving klass java/lang/System at 102
# Resolving klass java/lang/Double at 130
# Resolving klass java/lang/Integer at 136
# Resolving klass java/util/ArrayList at 144
# Resolving klass java/nio/file/OpenOption at 148
# Resolving klass java/io/PrintWriter at 154
# Resolving klass java/io/BufferedWriter at 156
# Resolving klass java/lang/Long at 170
# Resolving klass java/lang/Exception at 278
# ProfileInjection: Profile injection completed successfully - resuming normal execution
# ProfileInjection: Successfully injected profile data from replay_pid48059_compid213_nocompile.log
# Ran 2,000 invocations
# Average: 524.7 µs | p95: 564 µs
# Done.
# - Cold results : cold_results.csv
# - Warm results : warm_results.csv
# - Profiles used: replay_pid48059_compid213_nocompile.log
# Running benchmark to generate profile data...
# CompileCommand: DumpReplay WordCountBenchmark.wordCount bool DumpReplay = true
# # Compiler replay data is saved as: replay_pid48083_compid98.log
# # Compiler replay data is saved as: replay_pid48083_compid207.log
# # Compiler replay data is saved as: replay_pid48083_compid211.log
# # Compiler replay data is saved as: replay_pid48083_compid215.log
# Ran 2,000 invocations
# Average: 529.5 µs | p95: 575 µs
# Selecting largest replay file...
# Original replay: replay_pid48083_compid215.log
# Stripped replay saved as: replay_pid48083_compid215_nocompile.log
# Running benchmark with no profile injection...
# Ran 2,000 invocations
# Average: 559.1 µs | p95: 590 µs
# Running benchmark with profile injection (no forced compile)...
# ProfileInjection: Starting profile injection
# Resolving klass jdk/internal/reflect/Reflection at 153
# Resolving klass java/util/Objects at 199
# Resolving klass jdk/internal/loader/BootLoader at 227
# Resolving klass jdk/internal/reflect/ReflectionFactory at 255
# Resolving klass java/lang/Class$ReflectionData at 363
# Resolving klass jdk/internal/misc/PreviewFeatures at 558
# Resolving klass java/lang/Class$Atomic at 843
# Resolving klass java/lang/PublicMethods$MethodList at 963
# Resolving klass jdk/internal/reflect/ReflectionFactory$GetReflectionFactoryAction at 1009
# Resolving klass java/lang/StringUTF16 at 48
# Resolving klass java/util/regex/Pattern at 700
# Resolving klass [Ljava/lang/String; at 799
# Resolving klass jdk/internal/reflect/Reflection at 90
# Resolving klass [Ljava/lang/Class; at 134
# Resolving klass jdk/internal/reflect/ReflectionFactory at 250
# Resolving klass jdk/internal/misc/VM at 256
# Resolving klass jdk/internal/reflect/Reflection at 25
# Resolving klass java/lang/reflect/Modifier at 101
# Resolving klass java/lang/CharacterData00 at 20
# Resolving klass jdk/internal/math/FloatingDecimal at 109
# Resolving klass jdk/internal/ref/Cleaner at 36
# Resolving klass java/lang/Void at 50
# Resolving klass [Ljava/lang/Object; at 99
# Resolving klass [Ljava/lang/Class; at 101
# Resolving klass jdk/internal/reflect/MagicAccessorImpl at 2
# Resolving klass java/lang/invoke/MethodHandleNatives at 23
# Resolving klass java/util/ArrayList$SubList at 276
# Resolving klass java/lang/Object at 4
# Resolving klass java/lang/String at 9
# Resolving klass java/nio/file/Paths at 12
# Resolving klass java/nio/charset/StandardCharsets at 18
# Resolving klass java/nio/file/Files at 24
# Resolving klass java/lang/Character at 46
# Resolving klass java/lang/Math at 62
# Resolving klass java/util/List at 86
# Resolving klass java/lang/System at 102
# Resolving klass java/lang/Double at 130
# Resolving klass java/lang/Integer at 136
# Resolving klass java/util/ArrayList at 144
# Resolving klass java/nio/file/OpenOption at 148
# Resolving klass java/io/PrintWriter at 154
# Resolving klass java/io/BufferedWriter at 156
# Resolving klass java/lang/Long at 170
# Resolving klass java/lang/Exception at 278
# ProfileInjection: Profile injection completed successfully - resuming normal execution
# ProfileInjection: Successfully injected profile data from replay_pid48083_compid215_nocompile.log
# Ran 2,000 invocations
# Average: 452.3 µs | p95: 495 µs
# Done.
# - Cold results : cold_results.csv
# - Warm results : warm_results.csv
# - Profiles used: replay_pid48083_compid215_nocompile.log
# Running benchmark to generate profile data...
# CompileCommand: DumpReplay WordCountBenchmark.wordCount bool DumpReplay = true
# # Compiler replay data is saved as: replay_pid48113_compid98.log
# # Compiler replay data is saved as: replay_pid48113_compid206.log
# # Compiler replay data is saved as: replay_pid48113_compid210.log
# # Compiler replay data is saved as: replay_pid48113_compid214.log
# Ran 2,000 invocations
# Average: 536.2 µs | p95: 591 µs
# Selecting largest replay file...
# Original replay: replay_pid48113_compid214.log
# Stripped replay saved as: replay_pid48113_compid214_nocompile.log
# Running benchmark with no profile injection...
# Ran 2,000 invocations
# Average: 545.2 µs | p95: 585 µs
# Running benchmark with profile injection (no forced compile)...
# ProfileInjection: Starting profile injection
# Resolving klass jdk/internal/reflect/Reflection at 153
# Resolving klass java/util/Objects at 199
# Resolving klass jdk/internal/loader/BootLoader at 227
# Resolving klass jdk/internal/reflect/ReflectionFactory at 255
# Resolving klass java/lang/Class$ReflectionData at 363
# Resolving klass jdk/internal/misc/PreviewFeatures at 558
# Resolving klass java/lang/Class$Atomic at 843
# Resolving klass java/lang/PublicMethods$MethodList at 963
# Resolving klass jdk/internal/reflect/ReflectionFactory$GetReflectionFactoryAction at 1009
# Resolving klass java/lang/StringUTF16 at 48
# Resolving klass java/util/regex/Pattern at 700
# Resolving klass [Ljava/lang/String; at 799
# Resolving klass jdk/internal/reflect/Reflection at 90
# Resolving klass [Ljava/lang/Class; at 134
# Resolving klass jdk/internal/reflect/ReflectionFactory at 250
# Resolving klass jdk/internal/misc/VM at 256
# Resolving klass jdk/internal/reflect/Reflection at 25
# Resolving klass java/lang/reflect/Modifier at 101
# Resolving klass java/lang/CharacterData00 at 20
# Resolving klass jdk/internal/math/FloatingDecimal at 109
# Resolving klass jdk/internal/ref/Cleaner at 36
# Resolving klass java/lang/Void at 50
# Resolving klass [Ljava/lang/Object; at 99
# Resolving klass [Ljava/lang/Class; at 101
# Resolving klass jdk/internal/reflect/MagicAccessorImpl at 2
# Resolving klass java/lang/invoke/MethodHandleNatives at 23
# Resolving klass java/util/ArrayList$SubList at 276
# Resolving klass java/lang/Object at 4
# Resolving klass java/lang/String at 9
# Resolving klass java/nio/file/Paths at 12
# Resolving klass java/nio/charset/StandardCharsets at 18
# Resolving klass java/nio/file/Files at 24
# Resolving klass java/lang/Character at 46
# Resolving klass java/lang/Math at 62
# Resolving klass java/util/List at 86
# Resolving klass java/lang/System at 102
# Resolving klass java/lang/Double at 130
# Resolving klass java/lang/Integer at 136
# Resolving klass java/util/ArrayList at 144
# Resolving klass java/nio/file/OpenOption at 148
# Resolving klass java/io/PrintWriter at 154
# Resolving klass java/io/BufferedWriter at 156
# Resolving klass java/lang/Long at 170
# Resolving klass java/lang/Exception at 278
# ProfileInjection: Profile injection completed successfully - resuming normal execution
# ProfileInjection: Successfully injected profile data from replay_pid48113_compid214_nocompile.log
# Ran 2,000 invocations
# Average: 528.6 µs | p95: 568 µs
# Done.
# - Cold results : cold_results.csv
# - Warm results : warm_results.csv
# - Profiles used: replay_pid48113_compid214_nocompile.log
# Running benchmark to generate profile data...
# CompileCommand: DumpReplay WordCountBenchmark.wordCount bool DumpReplay = true
# # Compiler replay data is saved as: replay_pid48145_compid97.log
# # Compiler replay data is saved as: replay_pid48145_compid207.log
# # Compiler replay data is saved as: replay_pid48145_compid211.log
# # Compiler replay data is saved as: replay_pid48145_compid214.log
# Ran 2,000 invocations
# Average: 536.8 µs | p95: 579 µs
# Selecting largest replay file...
# Original replay: replay_pid48145_compid214.log
# Stripped replay saved as: replay_pid48145_compid214_nocompile.log
# Running benchmark with no profile injection...
# Ran 2,000 invocations
# Average: 544.4 µs | p95: 577 µs
# Running benchmark with profile injection (no forced compile)...
# ProfileInjection: Starting profile injection
# Resolving klass jdk/internal/reflect/Reflection at 153
# Resolving klass java/util/Objects at 199
# Resolving klass jdk/internal/loader/BootLoader at 227
# Resolving klass jdk/internal/reflect/ReflectionFactory at 255
# Resolving klass java/lang/Class$ReflectionData at 363
# Resolving klass jdk/internal/misc/PreviewFeatures at 558
# Resolving klass java/lang/Class$Atomic at 843
# Resolving klass java/lang/PublicMethods$MethodList at 963
# Resolving klass jdk/internal/reflect/ReflectionFactory$GetReflectionFactoryAction at 1009
# Resolving klass java/lang/StringUTF16 at 48
# Resolving klass java/util/regex/Pattern at 700
# Resolving klass [Ljava/lang/String; at 799
# Resolving klass jdk/internal/reflect/Reflection at 90
# Resolving klass [Ljava/lang/Class; at 134
# Resolving klass jdk/internal/reflect/ReflectionFactory at 250
# Resolving klass jdk/internal/misc/VM at 256
# Resolving klass jdk/internal/reflect/Reflection at 25
# Resolving klass java/lang/reflect/Modifier at 101
# Resolving klass java/lang/CharacterData00 at 20
# Resolving klass jdk/internal/math/FloatingDecimal at 109
# Resolving klass java/lang/Void at 50
# Resolving klass [Ljava/lang/Object; at 99
# Resolving klass [Ljava/lang/Class; at 101
# Resolving klass jdk/internal/reflect/MagicAccessorImpl at 2
# Resolving klass java/util/ArrayList$SubList at 276
# Resolving klass java/lang/Object at 4
# Resolving klass java/lang/String at 9
# Resolving klass java/nio/file/Paths at 12
# Resolving klass java/nio/charset/StandardCharsets at 18
# Resolving klass java/nio/file/Files at 24
# Resolving klass java/lang/Character at 46
# Resolving klass java/lang/Math at 62
# Resolving klass java/util/List at 86
# Resolving klass java/lang/System at 102
# Resolving klass java/lang/Double at 130
# Resolving klass java/lang/Integer at 136
# Resolving klass java/util/ArrayList at 144
# Resolving klass java/nio/file/OpenOption at 148
# Resolving klass java/io/PrintWriter at 154
# Resolving klass java/io/BufferedWriter at 156
# Resolving klass java/lang/Long at 170
# Resolving klass java/lang/Exception at 278
# ProfileInjection: Profile injection completed successfully - resuming normal execution
# ProfileInjection: Successfully injected profile data from replay_pid48145_compid214_nocompile.log
# Ran 2,000 invocations
# Average: 522.1 µs | p95: 562 µs
# Done.
# - Cold results : cold_results.csv
# - Warm results : warm_results.csv
# - Profiles used: replay_pid48145_compid214_nocompile.log
# Running benchmark to generate profile data...
# CompileCommand: DumpReplay WordCountBenchmark.wordCount bool DumpReplay = true
# # Compiler replay data is saved as: replay_pid48175_compid97.log
# # Compiler replay data is saved as: replay_pid48175_compid205.log
# # Compiler replay data is saved as: replay_pid48175_compid209.log
# # Compiler replay data is saved as: replay_pid48175_compid214.log
# Ran 2,000 invocations
# Average: 572.1 µs | p95: 585 µs
# Selecting largest replay file...
# Original replay: replay_pid48175_compid214.log
# Stripped replay saved as: replay_pid48175_compid214_nocompile.log
# Running benchmark with no profile injection...
# Ran 2,000 invocations
# Average: 525.1 µs | p95: 569 µs
# Running benchmark with profile injection (no forced compile)...
# ProfileInjection: Starting profile injection
# Resolving klass jdk/internal/reflect/Reflection at 153
# Resolving klass java/util/Objects at 199
# Resolving klass jdk/internal/loader/BootLoader at 227
# Resolving klass jdk/internal/reflect/ReflectionFactory at 255
# Resolving klass java/lang/Class$ReflectionData at 363
# Resolving klass jdk/internal/misc/PreviewFeatures at 558
# Resolving klass java/lang/Class$Atomic at 843
# Resolving klass java/lang/PublicMethods$MethodList at 963
# Resolving klass jdk/internal/reflect/ReflectionFactory$GetReflectionFactoryAction at 1009
# Resolving klass java/lang/StringUTF16 at 48
# Resolving klass java/util/regex/Pattern at 700
# Resolving klass [Ljava/lang/String; at 799
# Resolving klass jdk/internal/reflect/Reflection at 90
# Resolving klass [Ljava/lang/Class; at 134
# Resolving klass jdk/internal/reflect/ReflectionFactory at 250
# Resolving klass jdk/internal/misc/VM at 256
# Resolving klass jdk/internal/reflect/Reflection at 25
# Resolving klass java/lang/reflect/Modifier at 101
# Resolving klass java/lang/CharacterData00 at 20
# Resolving klass jdk/internal/math/FloatingDecimal at 109
# Resolving klass java/lang/Void at 50
# Resolving klass [Ljava/lang/Object; at 99
# Resolving klass [Ljava/lang/Class; at 101
# Resolving klass jdk/internal/reflect/MagicAccessorImpl at 2
# Resolving klass java/util/ArrayList$SubList at 276
# Resolving klass java/lang/Object at 4
# Resolving klass java/lang/String at 9
# Resolving klass java/nio/file/Paths at 12
# Resolving klass java/nio/charset/StandardCharsets at 18
# Resolving klass java/nio/file/Files at 24
# Resolving klass java/lang/Character at 46
# Resolving klass java/lang/Math at 62
# Resolving klass java/util/List at 86
# Resolving klass java/lang/System at 102
# Resolving klass java/lang/Double at 130
# Resolving klass java/lang/Integer at 136
# Resolving klass java/util/ArrayList at 144
# Resolving klass java/nio/file/OpenOption at 148
# Resolving klass java/io/PrintWriter at 154
# Resolving klass java/io/BufferedWriter at 156
# Resolving klass java/lang/Long at 170
# Resolving klass java/lang/Exception at 278
# ProfileInjection: Profile injection completed successfully - resuming normal execution
# ProfileInjection: Successfully injected profile data from replay_pid48175_compid214_nocompile.log
# Ran 2,000 invocations
# Average: 454.8 µs | p95: 490 µs
# Done.
# - Cold results : cold_results.csv
# - Warm results : warm_results.csv
# - Profiles used: replay_pid48175_compid214_nocompile.log

# %%
# Load every captured CSV
cold_frames = [pd.read_csv(f) for f in sorted(glob.glob("cold_results_*"))]
warm_frames = [pd.read_csv(f) for f in sorted(glob.glob("warm_results_*"))]

assert cold_frames and warm_frames, "No results found – did run.sh succeed?"

# Average per‑invocation index
cold_avg = (
    pd.concat(cold_frames)
      .groupby("invocation", as_index=False)["time_us"]
      .mean()
      .rename(columns={"time_us": "cold_avg"})
)

warm_avg = (
    pd.concat(warm_frames)
      .groupby("invocation", as_index=False)["time_us"]
      .mean()
      .rename(columns={"time_us": "warm_avg"})
)

merged = cold_avg.merge(warm_avg, on="invocation")
merged.head()
# Out:
#    invocation  cold_avg  warm_avg
# 0           1    4604.0    4515.2
# 1           2    2613.6     692.5
# 2           3     699.7     614.0
# 3           4     697.8    1843.1
# 4           5     679.6     715.6

# %%
plt.figure(figsize=(10, 6))
plt.plot(merged["invocation"], merged["cold_avg"], label="Cold avg")
plt.plot(merged["invocation"], merged["warm_avg"], label="Warm avg")
plt.xlabel("Invocation #")
plt.ylabel("μs per invocation (average across runs)")
plt.ylim(200, 800)
plt.xlim(0, 300)
plt.title(f"Latency comparison over {NUM_RUNS} runs")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# --- summary statistics --------------------------------------------------
def describe(series, label):
    print(f"\n{label}:")
    print(f"  • overall mean     : {series.mean():8.1f} µs")
    print(f"  • overall median   : {series.median():8.1f} µs")
    print(f"  • overall p95      : {series.quantile(0.95):8.1f} µs")

# Define the “plateau” as the last 20 % of invocations
plateau_start = int(0.8 * merged["invocation"].max())
plateau = merged[merged["invocation"] >= plateau_start]

cold_plateau_mean = plateau["cold_avg"].mean()
warm_plateau_mean = plateau["warm_avg"].mean()
speedup = (cold_plateau_mean - warm_plateau_mean) / cold_plateau_mean * 100

describe(merged["cold_avg"], "Cold run")
describe(merged["warm_avg"], "Warm run")

print(f"\nPlateau window (invocation ≥ {plateau_start}):")
print(f"  • cold mean  : {cold_plateau_mean:.1f} µs")
print(f"  • warm mean  : {warm_plateau_mean:.1f} µs")
print(f"  • warm faster by : {speedup:.2f}%")
# Out:
# Cold run:
#   • overall mean     :    545.0 µs
#   • overall median   :    522.2 µs
#   • overall p95      :    608.0 µs
#
# Warm run:
#   • overall mean     :    517.6 µs
#   • overall median   :    492.3 µs
#   • overall p95      :    562.9 µs
#
# Plateau window (invocation ≥ 1600):
#   • cold mean  : 523.4 µs
#   • warm mean  : 510.5 µs
#   • warm faster by : 2.46%

# %%
rm -rf *.csv *.log cold_results* warm_results*
